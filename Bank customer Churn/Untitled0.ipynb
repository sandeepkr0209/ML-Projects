# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Customer-Churn-Records.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %% [markdown]
# # Data Exploring

# %%
data.sample()
# Out:
#     RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 47         48    15771573  Okagbue          637   Germany  Female   39
#
#     Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 47       9  137843.8              1          1               1
#
#     EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 47         117622.8       1         1                   1    SILVER
#
#     Point Earned
# 47           730

# %%
data.shape
# Out:
# (10000, 18)

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %% [markdown]
# ## we need to convert three categorical columms into numerical columns

# %% [markdown]
# ###Geography, Gender, Card Type

# %% [markdown]
# ## Dropping the Irrelevant columns

# %%
data = data.drop(columns=['Surname', 'RowNumber', 'CustomerId'], axis=1)

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction Score Card Type  Point Earned
# 0                   2   DIAMOND           464
# 1                   3   DIAMOND           456
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CreditScore         10000 non-null  int64
#  1   Geography           10000 non-null  object
#  2   Gender              10000 non-null  object
#  3   Age                 10000 non-null  int64
#  4   Tenure              10000 non-null  int64
#  5   Balance             10000 non-null  float64
#  6   NumOfProducts       10000 non-null  int64
#  7   HasCrCard           10000 non-null  int64
#  8   IsActiveMember      10000 non-null  int64
#  9   EstimatedSalary     10000 non-null  float64
#  10  Exited              10000 non-null  int64
#  11  Complain            10000 non-null  int64
#  12  Satisfaction Score  10000 non-null  int64
#  13  Card Type           10000 non-null  object
#  14  Point Earned        10000 non-null  int64
# dtypes: float64(2), int64(10), object(3)
# ...

# %%
data['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
data['Card Type'].unique()
# Out:
# array(['DIAMOND', 'GOLD', 'SILVER', 'PLATINUM'], dtype=object)

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data.isnull().sum()
# Out:
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %% [markdown]
# # Data is Imbalanced we will perfrom SMOTE technique after tranaformation

# %%
data['Exited'].value_counts()
# Out:
# Exited
# 0    7962
# 1    2038
# Name: count, dtype: int64

# %% [markdown]
# # Define Input and Output data

# %%
X = data.drop(columns=['Exited'])
y = data['Exited']

# %%
X.shape
# Out:
# (10000, 14)

# %%
y.shape
# Out:
# (10000,)

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Complain  Satisfaction Score  \
# 0          1               1        101348.88         1                   2
# 1          0               1        112542.58         1                   3
# 2          1               0        113931.57         1                   3
# 3          0               0         93826.63         0                   5
# 4          1               1         79084.10         0                   5
#
#   Card Type  Point Earned
# 0   DIAMOND           464
# ...

# %% [markdown]
# # Converting Categorical columns into numerical using OneHotEncoding

# %%
cat_cols= ['Geography', 'Gender', 'Card Type']
num_cols = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Complain', 'Satisfaction Score', 'Point Earned']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

preprocess = ColumnTransformer(transformers=[
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), cat_cols)
])

# %%
X_scaled = preprocess.fit_transform(X_train)
X_test_scaled = preprocess.transform(X_test)

# %%
X_scaled.shape
# Out:
# (8000, 17)

# %%
X_test_scaled.shape
# Out:
# (2000, 17)

# %%
print(X_scaled)
# Out:
# [[ 1.03360928  0.00825566  0.34955973 ...  0.          1.
#    0.        ]
#  [ 0.78536369 -0.46826153 -0.69053865 ...  0.          1.
#    0.        ]
#  [-0.64204841  2.39084161 -0.69053865 ...  0.          0.
#    1.        ]
#  ...
#  [-0.69376624 -0.75417184 -0.34383919 ...  0.          0.
#    0.        ]
#  [ 0.29921609 -0.27765465  0.34955973 ...  0.          1.
#    0.        ]
#  [-1.66606145  1.24720035 -1.38393756 ...  1.          0.
#    0.        ]]

# %% [markdown]
# # Balanced the data Using SMOTE only on training data

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X_train1, y_train1 = smote.fit_resample(X_scaled, y_train)

# %%
X_train1.shape
# Out:
# (12734, 17)

# %%
y_train1.value_counts()
# Out:
# Exited
# 0    6367
# 1    6367
# Name: count, dtype: int64

# %%
X_train.shape, y_train.shape
# Out:
# ((8000, 14), (8000,))

# %% [markdown]
# # Now everything is done, next step is to do model training

# %% [markdown]
# ##1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train1, y_train1)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Evaluation of 1st model

# %%
y_pred1 = lr.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print(accuracy_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
print(classification_report(y_test, y_pred1))
# Out:
# 0.9995
# [[1594    1]
#  [   0  405]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1595
#            1       1.00      1.00      1.00       405
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %% [markdown]
# ## 2. Model

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(X_train1, y_train1)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
# Out:
# 0.9985
# [[1593    2]
#  [   1  404]]

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1595
#            1       1.00      1.00      1.00       405
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %% [markdown]
# ## 3. SVM

# %%
from sklearn.svm import SVC

svm = SVC()

svm.fit(X_train1, y_train1)
# Out:
# SVC()

# %%
y_pred3 = svm.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
# Out:
# 0.9995
# [[1594    1]
#  [   0  405]]

# %%
print(classification_report(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1595
#            1       1.00      1.00      1.00       405
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %% [markdown]
# ##4. KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn.fit(X_train1, y_train1)
# Out:
# KNeighborsClassifier()

# %%
y_pred4 = knn.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred4))
print(confusion_matrix(y_test, y_pred4))
# Out:
# 0.9995
# [[1594    1]
#  [   0  405]]

# %%
print(classification_report(y_test, y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1595
#            1       1.00      1.00      1.00       405
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %% [markdown]
# ##5. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)

rf.fit(X_train1, y_train1)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred5 = rf.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred5))
print(confusion_matrix(y_test, y_pred5))
# Out:
# 0.9995
# [[1594    1]
#  [   0  405]]

# %% [markdown]
# ##6. Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()

gb.fit(X_train1, y_train1)
# Out:
# GradientBoostingClassifier()

# %%
y_pred6 = gb.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred6))
print(confusion_matrix(y_test, y_pred6))
# Out:
# 0.999
# [[1593    2]
#  [   0  405]]

# %%
print(classification_report(y_test, y_pred6))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1595
#            1       1.00      1.00      1.00       405
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %%
final_data = pd.DataFrame({'Models': ['LR', 'SVC', 'KNN','DT', 'RF', 'GBC'], 'ACC': [accuracy_score(y_test,y_pred1),
                                                                                    accuracy_score(y_test,y_pred2),
                                                                                    accuracy_score(y_test,y_pred3),
                                                                                    accuracy_score(y_test,y_pred4),
                                                                                    accuracy_score(y_test,y_pred5),
                                                                                    accuracy_score(y_test,y_pred6),]})

# %%
final_data
# Out:
#   Models     ACC
# 0     LR  0.9995
# 1    SVC  0.9985
# 2    KNN  0.9995
# 3     DT  0.9995
# 4     RF  0.9995
# 5    GBC  0.9990

# %% [markdown]
# # Creating Pipeline using Random Forest Model

# %%
model = RandomForestClassifier(n_estimators=1000)

# %%
from imblearn.pipeline import Pipeline

# %%
pipeline = Pipeline([
    ('preprocess', preprocess),
    ('smote', SMOTE(random_state=42)),
    ('model', model)
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['CreditScore', 'Age',
#                                                    'Tenure', 'Balance',
#                                                    'NumOfProducts', 'HasCrCard',
#                                                    'IsActiveMember',
#                                                    'EstimatedSalary',
#                                                    'Complain',
#                                                    'Satisfaction Score',
#                                                    'Point Earned']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
# ...

# %%
y_predd = pipeline.predict(X_test)

# %% [markdown]
# #Evaluation

# %%
print('Accuracy :', accuracy_score(y_test, y_predd))
# Out:
# Accuracy : 0.9995

# %%
print('Confusion Matrix :\n', confusion_matrix(y_test, y_predd))
# Out:
# Confusion Matrix :
#  [[1594    1]
#  [   0  405]]

# %%
print('Classification Report : \n', classification_report(y_test, y_predd))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1595
#            1       1.00      1.00      1.00       405
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %%
from sklearn.metrics import precision_score, f1_score

# %%
print('Precision Score :' , precision_score(y_test, y_predd))
# Out:
# Precision Score : 0.9975369458128078

# %%
print('f1 Score :', f1_score(y_test, y_predd, average='weighted'))
# Out:
# f1 Score : 0.9995002298669247

# %% [markdown]
# #Exporting/Save the Model

# %%
import joblib

joblib.dump(pipeline, 'churn_pipeline.pkl')
# Out:
# ['churn_pipeline.pkl']

# %%
from tkinter import *
